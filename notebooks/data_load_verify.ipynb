# %% [markdown]
# # Test Notebook
# **Arkesh Das**
#
# This notebook ensures that the Sagemaker AI instance is set up properly and that it can connect to my aws bucket. In for these cells and the queries in these cells to run, the database must have been initialized using [these queries](../sql/nyc311_db_init.sql).
#
# Additionally, this notebook was ran on a Amazon Sagemaker AI notebook instance. The data will not load without the packages inside that environment, unless remote access is set-up.

# %%
# Import initial libraries
import pandas as pd
import numpy as np
import boto3
from io import StringIO
import matplotlib.pyplot as plt

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %%
# Test 2: Connect to S3
s3 = boto3.client('s3')
response = s3.list_buckets()
bucket_count = len(response['Buckets'])

print(f"Connected to S3")
print(f"Found {bucket_count} S3 buckets")

# Print your buckets (to identify your modeling data bucket)
for bucket in response['Buckets']:
    print(f"  - {bucket['Name']}")
# Out:
# Connected to S3
# Found 1 S3 buckets
#   - cmse492-dasarkes-nyc311-471112527784-us-east-1-an

# %%
s3 = boto3.client('s3')
bucket_name = 'cmse492-dasarkes-nyc311-471112527784-us-east-1-an'
file_name = 'modeling/q2_modeling_data.csv' 
obj = s3.get_object(Bucket=bucket_name, Key=file_name)
data = obj['Body'].read().decode('utf-8')
df = pd.read_csv(StringIO(data))
dr = df.dropna()

# %%
# First few rows
print("First few rows:")
print(df.head())

# Data types and missing values
print("\n" + "="*50)
print("Data types and missing values:")
print(df.info())
# Out:
# First few rows:
#   agency   borough             problem  incident_zip  day_of_week  \
# 0   DCWP     BRONX  Consumer Complaint       10455.0            5
# 1   DCWP  BROOKLYN  Consumer Complaint       11207.0            5
# 2   DCWP  BROOKLYN  Consumer Complaint       11234.0            5
# 3   DCWP     BRONX  Consumer Complaint       10454.0            5
# 4   DCWP    QUEENS  Consumer Complaint       11423.0            5
#
#    hour_of_day  same_day_complaint_volume  days_to_close
# 0           13                         19             33
# 1           11                         19              4
# 2            3                         19             34
# 3           11                         19             33
# 4           15                         19             33
#
# ...
# Data types and missing values:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173851 entries, 0 to 173850
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count   Dtype
# ...

# %% [markdown]
# **Hooray the data loads!**
